# %%
import sys
import os
import platform
import pydicom
import SimpleITK as sitk
import radiomics

# %%
# Check system paths to ensure we are in the right environment
print("Python Executable: " + sys.executable)
print("Current Directory: " + os.getcwd())

print("\nLibrary Search Paths:")
for path in sys.path:
    print(path)
# Out:
# Python Executable: /home/daniduhnev/miniconda3/envs/thesis_env/bin/python
# Current Directory: /home/daniduhnev/projects/master-thesis/analysis
#
# Library Search Paths:
# /home/daniduhnev/miniconda3/envs/thesis_env/lib/python39.zip
# /home/daniduhnev/miniconda3/envs/thesis_env/lib/python3.9
# /home/daniduhnev/miniconda3/envs/thesis_env/lib/python3.9/lib-dynload
#
# /home/daniduhnev/miniconda3/envs/thesis_env/lib/python3.9/site-packages

# %%
# Verify library installations and versions
print(f"System: {platform.system()}")
print(f"Pydicom Version: {pydicom.__version__}")
print(f"SimpleITK Version: {sitk.Version().VersionString()}")
print(f"Radiomics Version: {radiomics.__version__}")

print("\nEnvironment check passed.")
# Out:
# System: Linux
# Pydicom Version: 2.4.4
# SimpleITK Version: 2.5.3
# Radiomics Version: v3.1.0
#
# Environment check passed.
