# %%
import sys
import os
import platform
import pydicom
import SimpleITK as sitk
import radiomics

# %%
# Check system paths to ensure we are in the right environment
print("Python Executable: " + sys.executable)
print("Current Directory: " + os.getcwd())

print("\nLibrary Search Paths:")
for path in sys.path:
    print(path)
# Out:
# Python Executable: /opt/homebrew/Caskroom/miniconda/base/envs/thesis_env/bin/python
# Current Directory: /Users/kmwg649/Desktop/repos/master-thesis/pancreas-us-radiomics/analysis
#
# Library Search Paths:
# /opt/homebrew/Caskroom/miniconda/base/envs/thesis_env/lib/python39.zip
# /opt/homebrew/Caskroom/miniconda/base/envs/thesis_env/lib/python3.9
# /opt/homebrew/Caskroom/miniconda/base/envs/thesis_env/lib/python3.9/lib-dynload
#
# /opt/homebrew/Caskroom/miniconda/base/envs/thesis_env/lib/python3.9/site-packages

# %%
# Verify library installations and versions
print(f"System: {platform.system()}")
print(f"Pydicom Version: {pydicom.__version__}")
print(f"SimpleITK Version: {sitk.Version().VersionString()}")
print(f"Radiomics Version: {radiomics.__version__}")

print("\nEnvironment check passed.")
# Out:
# System: Darwin
# Pydicom Version: 2.4.4
# SimpleITK Version: 2.5.3
# Radiomics Version: v3.0.1
#
# Environment check passed.
